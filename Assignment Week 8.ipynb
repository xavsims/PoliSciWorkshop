# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# to ignore warnings:
import warnings
warnings.filterwarnings('ignore')

# %%
pwd
# Out:
# '/Users/xaviersims/Desktop/AMERICAN UNI CLASSES/Government Data Science'

# %%
qog = pd.read_csv("/Users/xaviersims/Desktop/AMERICAN UNI CLASSES/Government Data Science/qog.csv")

# %%
qog.head()
# Out:
#    ccode        cname  year ccodealp        cname_year ccodealp_year  \
# 0      4  Afghanistan  1946      AFG  Afghanistan 1946         AFG46
# 1      4  Afghanistan  1947      AFG  Afghanistan 1947         AFG47
# 2      4  Afghanistan  1948      AFG  Afghanistan 1948         AFG48
# 3      4  Afghanistan  1949      AFG  Afghanistan 1949         AFG49
# 4      4  Afghanistan  1950      AFG  Afghanistan 1950         AFG50
#
#    ccodecow  ccodewb        version  aid_cpnc  ...  wwbi_rrespubpemp  \
# 0     700.0      4.0  QoGStdTSJan21       NaN  ...               NaN
# 1     700.0      4.0  QoGStdTSJan21       NaN  ...               NaN
# 2     700.0      4.0  QoGStdTSJan21       NaN  ...               NaN
# 3     700.0      4.0  QoGStdTSJan21       NaN  ...               NaN
# 4     700.0      4.0  QoGStdTSJan21       NaN  ...               NaN
#
#    wwbi_sprpempn  wwbi_sprpempp  wwbi_sprpemps  wwbi_sprpempt  wwbi_spupempn  \
# ...

# %%
qog.groupby(["cname"]).mean()
# Out:
#               ccode  year  ccodecow  ccodewb  aid_cpnc  aid_cpsc   aid_crnc  \
# cname
# Afghanistan       4  1983     700.0      4.0       NaN       NaN  14.268293
# Albania           8  1983     339.0      8.0       NaN       NaN  16.833333
# Algeria          12  1983     615.0     12.0       NaN       NaN  11.255814
# Andorra          20  1983     232.0     20.0       NaN       NaN        NaN
# Angola           24  1983     540.0     24.0       NaN       NaN  14.578947
# ...             ...   ...       ...      ...       ...       ...        ...
# Yemen, North    886  1983       NaN      NaN       NaN       NaN   7.700000
# Yemen, South    720  1983       NaN    720.0       NaN       NaN        NaN
# Yugoslavia      890  1983     345.0    891.0       NaN       NaN   1.083333
# Zambia          894  1983     551.0    894.0       NaN       NaN  15.365854
# Zimbabwe        716  1983     552.0    716.0       NaN       NaN  15.589744
#
# ...

# %%
qog.groupby(["cname","dr_pg"]).mean()
# Out:
#                        ccode    year  ccodecow  ccodewb  aid_cpnc  aid_cpsc  \
# cname       dr_pg
# Afghanistan 18.481024    4.0  1970.0     700.0      4.0       NaN       NaN
#             19.242987    4.0  1972.0     700.0      4.0       NaN       NaN
#             19.980864    4.0  1971.0     700.0      4.0       NaN       NaN
#             20.004948    4.0  1973.0     700.0      4.0       NaN       NaN
#             20.204470    4.0  1974.0     700.0      4.0       NaN       NaN
# ...                      ...     ...       ...      ...       ...       ...
# Zimbabwe    69.549965  716.0  2008.0     552.0    716.0       NaN       NaN
#             69.691475  716.0  2010.0     552.0    716.0       NaN       NaN
#             70.057304  716.0  2009.0     552.0    716.0       NaN       NaN
#             70.204109  716.0  2016.0     552.0    716.0       NaN       NaN
#             70.767067  716.0  2015.0     552.0    716.0       NaN       NaN
#
# ...

# %%
qog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15825 entries, 0 to 15824
# Columns: 1864 entries, ccode to wwbi_tertiarypubsec
# dtypes: float64(1851), int64(2), object(11)
# memory usage: 225.1+ MB

# %%
#DISTRIBUTION PLOT
#sns.distplot(x = qog['ideavt_legvt'])
#sns.distplot(x = qog['dr_pg'], bins = 1000)
#sns.distplot(x = qog.groupby(["cname == Afghanistan","ideavt_legvt"]).mean(), bins = 1)
#sns.distplot(x = qog.groupby(["cname","ideavt_legvt"]).mean(), bins = 1)
sns.distplot(x = qog["ideavt_legvt"], bins = 1)
#qog.groupby(["cname","dr_pg"]).mean()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#JOINT PLOT
#sns.jointplot(x=titanic['age'], y=titanic['fare'], kind='scatter')
sns.jointplot(x = qog["ideavt_legvt"], y = qog["dr_pg"], kind='scatter')

# %%
#PAIR PLOT
#sns.pairplot(titanic)


sns.pairplot(qog)
quit()

# %%
#RUG PLOT
#sns.rugplot(x=titanic['fare'])

sns.rugplot(x = qog["ideavt_legvt"])
# Out:
# <AxesSubplot:xlabel='ideavt_legvt'>

# %%
#BAR PLOT
#bivariate analysis

#x-axis: categorical variable
#y-axis: continuous variable

sns.barplot(x = qog["cname"], y = qog["ideavt_legvt"])
# Out:
# <AxesSubplot:xlabel='cname', ylabel='ideavt_legvt'>

# %%
#COUNT PLOT
#good for univarite analysis:
#measures number of occurence for a categorical variable
sns.countplot(qog["ideavt_legvt"])
# Out:
# <AxesSubplot:xlabel='ideavt_legvt', ylabel='count'>

# %%
#BOX PLOT, continuous variable

#sns.boxplot(x=titanic['pclass'])
#BOXPLOT TWO
sns.boxplot(x = qog["cname"], y = qog["ideavt_legvt"])
# Out:
# <AxesSubplot:xlabel='cname', ylabel='ideavt_legvt'>

# %%
#VIOLIN PLOT
# similar to box plot 
# shows us xtra info about 
sns.violinplot(x = qog["cname"], y = qog["ideavt_legvt"])
# Out:
# <AxesSubplot:xlabel='cname', ylabel='ideavt_legvt'>
